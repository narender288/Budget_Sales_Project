# %% [markdown]
# # PROJECT - BUDGET SALES ANALYTICS

# %%
import pandas as pd
df = pd.read_excel("C:/Users/DELL/OneDrive/Desktop/PYTHON PROGRAM/ANACONDA/unified mentor/AdventureWorks_Database.xlsx")
df
# Out:
#            Date   DateKey  Year Quarter  MonthNum Month FiscalYear  \
# 0    2016-04-03  20160403  2016      Q2         4   Apr     FY2016
# 1    2016-04-04  20160404  2016      Q2         4   Apr     FY2016
# 2    2016-04-05  20160405  2016      Q2         4   Apr     FY2016
# 3    2016-04-06  20160406  2016      Q2         4   Apr     FY2016
# 4    2016-04-07  20160407  2016      Q2         4   Apr     FY2016
# ...         ...       ...   ...     ...       ...   ...        ...
# 1456 2014-06-18  20140618  2014      Q2         6   Jun     FY2014
# 1457 2014-06-19  20140619  2014      Q2         6   Jun     FY2014
# 1458 2014-06-20  20140620  2014      Q2         6   Jun     FY2014
# 1459 2014-06-21  20140621  2014      Q2         6   Jun     FY2014
# 1460 2014-06-22  20140622  2014      Q2         6   Jun     FY2014
#
#      FiscalQuarter  FiscalMonthNum FiscalMonth MonthYear MonthYearLong  \
# 0              FQ4              10         Apr    Apr-16      Apr-2016
# ...

# %%
df2 = pd.read_excel("C:/Users/DELL/OneDrive/Desktop/PYTHON PROGRAM/ANACONDA/unified mentor/Budget.xlsx")
df2
# Out:
#      AdventureWorks Budget Data         Unnamed: 1  \
# 0     Prepared By: Johnny Bunko                NaN
# 1   AdventureWorks Confidential                NaN
# 2                      Category        Subcategory
# 3                   Accessories         Bike Racks
# 4                   Accessories        Bike Stands
# 5                   Accessories  Bottles and Cages
# 6                   Accessories           Cleaners
# 7                   Accessories            Fenders
# 8                   Accessories            Helmets
# 9                   Accessories    Hydration Packs
# 10                  Accessories    Tires and Tubes
# 11         SubTotal Accessories                NaN
# 12                        Bikes     Mountain Bikes
# 13                        Bikes         Road Bikes
# 14                        Bikes      Touring Bikes
# 15               SubTotal Bikes                NaN
# 16                     Clothing               Caps
# ...

# %%
# lets start with collecting info regarding the provided dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            1461 non-null   datetime64[ns]
#  1   DateKey         1461 non-null   int64
#  2   Year            1461 non-null   int64
#  3   Quarter         1461 non-null   object
#  4   MonthNum        1461 non-null   int64
#  5   Month           1461 non-null   object
#  6   FiscalYear      1461 non-null   object
#  7   FiscalQuarter   1461 non-null   object
#  8   FiscalMonthNum  1461 non-null   int64
#  9   FiscalMonth     1461 non-null   object
#  10  MonthYear       1461 non-null   object
#  11  MonthYearLong   1461 non-null   object
#  12  MonthYearNum    1461 non-null   int64
#  13  WeekdayNum      1461 non-null   int64
#  14  Weekday         1461 non-null   object
#  15  WeekdayWeekend  1461 non-null   object
# dtypes: datetime64[ns](1), int64(6), object(9)
# ...

# %%
# we can se no entry is zero is our df1

# %%
df2.isnull().sum()
# Out:
# AdventureWorks Budget Data    0
# Unnamed: 1                    6
# Unnamed: 2                    6
# Unnamed: 3                    6
# Unnamed: 4                    2
# Unnamed: 5                    2
# Unnamed: 6                    2
# Unnamed: 7                    2
# Unnamed: 8                    2
# Unnamed: 9                    2
# Unnamed: 10                   2
# Unnamed: 11                   2
# Unnamed: 12                   2
# Unnamed: 13                   2
# Unnamed: 14                   2
# Unnamed: 15                   2
# Unnamed: 16                   2
# dtype: int64

# %%
# in dataframe 2 there are many zero values.

# %%
# IMPORTANT 
""" 
if we look at our given data set we face some issue like 
- missing value in columns (NaN)      (missing value)
- column S.No is of no use in analazing. (unnecceary data)
- improper name of column.(bad for good programmer) make it simple...
"""
# Out:
# ' \nif we look at our given data set we face some issue like \n- missing value in columns (NaN)      (missing value)\n- column S.No is of no use in analazing. (unnecceary data)\n- improper name of column.(bad for good programmer) make it simple...\n'

# %%
df2.drop(index=[2], inplace=True)
df2.drop(index=[0], inplace=True)

# %%
df2.drop(index=[1], inplace=True)

# %%
df2
# Out:
#    AdventureWorks Budget Data         Unnamed: 1                  Unnamed: 2  \
# 3                 Accessories         Bike Racks         Hitch Rack - 4-Bike
# 4                 Accessories        Bike Stands      All-Purpose Bike Stand
# 5                 Accessories  Bottles and Cages       Water Bottle - 30 oz.
# 6                 Accessories           Cleaners       Bike Wash - Dissolver
# 7                 Accessories            Fenders       Fender Set - Mountain
# 8                 Accessories            Helmets       Sport-100 Helmet, Red
# 9                 Accessories    Hydration Packs     Hydration Pack - 70 oz.
# 10                Accessories    Tires and Tubes         Patch Kit/8 Patches
# 11       SubTotal Accessories                NaN                         NaN
# 12                      Bikes     Mountain Bikes     Mountain-100 Silver, 38
# 13                      Bikes         Road Bikes            Road-150 Red, 62
# ...

# %%
df2.rename(columns = {'Unnamed: 1':'Subcategory' ,'Unnamed: 2':'Productname', 'Unnamed: 3':'ProductKey','Unnamed: 4':'Jan2016','Unnamed: 5':'Feb2016'},inplace = True)

# %%
df2.rename(columns = {'Unnamed: 6':'mar2016' ,'Unnamed: 7':'Apr2016', 'Unnamed: 8':'May2016','Unnamed: 9':'Jun2016','Unnamed: 10':'jul2016'}, inplace = True)

# %%
df2.rename(columns = {'Unnamed: 11':'Aug2016' ,'Unnamed: 12':'Sep2016', 'Unnamed: 13':'Oct2016','Unnamed: 14':'Nov2016','Unnamed: 15':'Dec2016' , 'Unnamed: 16':'GrandTotal'}, inplace = True)

# %%
df2
# Out:
#    AdventureWorks Budget Data        Subcategory                 Productname  \
# 3                 Accessories         Bike Racks         Hitch Rack - 4-Bike
# 4                 Accessories        Bike Stands      All-Purpose Bike Stand
# 5                 Accessories  Bottles and Cages       Water Bottle - 30 oz.
# 6                 Accessories           Cleaners       Bike Wash - Dissolver
# 7                 Accessories            Fenders       Fender Set - Mountain
# 8                 Accessories            Helmets       Sport-100 Helmet, Red
# 9                 Accessories    Hydration Packs     Hydration Pack - 70 oz.
# 10                Accessories    Tires and Tubes         Patch Kit/8 Patches
# 11       SubTotal Accessories                NaN                         NaN
# 12                      Bikes     Mountain Bikes     Mountain-100 Silver, 38
# 13                      Bikes         Road Bikes            Road-150 Red, 62
# ...

# %%
df2.isnull().sum()
# Out:
# AdventureWorks Budget Data    0
# Subcategory                   4
# Productname                   4
# ProductKey                    4
# Jan2016                       0
# Feb2016                       0
# mar2016                       0
# Apr2016                       0
# May2016                       0
# Jun2016                       0
# jul2016                       0
# Aug2016                       0
# Sep2016                       0
# Oct2016                       0
# Nov2016                       0
# Dec2016                       0
# GrandTotal                    0
# dtype: int64

# %%
# let's start with product key

# %%
x = df2.iloc[0:8:1 , 3:4:1].sum()
x
# Out:
# ProductKey    3594
# dtype: object

# %%
df2['ProductKey'][11] = 3594.0

# %%
x = df2.iloc[9:12:1 , 3:4:1].sum()
x
# Out:
# ProductKey    1214
# dtype: object

# %%
df2['ProductKey'][15] = 1214.0

# %%
x = df2.iloc[13:19:1 , 3:4:1].sum()    # 18 is filled by mean.
x
# Out:
# ProductKey    2045
# dtype: object

# %%
df2['ProductKey'][22] = 2045.0

# %%
x = df2.iloc[0:20:1 , 3:4:1].sum()
x
# Out:
# ProductKey    13706.0
# dtype: object

# %%
df2['ProductKey'][23] = 13706.0

# %%
df2.isnull().sum()
# Out:
# AdventureWorks Budget Data    0
# Subcategory                   4
# Productname                   4
# ProductKey                    0
# Jan2016                       0
# Feb2016                       0
# mar2016                       0
# Apr2016                       0
# May2016                       0
# Jun2016                       0
# jul2016                       0
# Aug2016                       0
# Sep2016                       0
# Oct2016                       0
# Nov2016                       0
# Dec2016                       0
# GrandTotal                    0
# dtype: int64

# %%
# missing values of product key get filled.

# %%
# now subcategory values.

# %%
df2.Subcategory.fillna('All' , inplace =True)
df2.Productname.fillna('All' , inplace =True)

# %%
df2
# Out:
#    AdventureWorks Budget Data        Subcategory                 Productname  \
# 3                 Accessories         Bike Racks         Hitch Rack - 4-Bike
# 4                 Accessories        Bike Stands      All-Purpose Bike Stand
# 5                 Accessories  Bottles and Cages       Water Bottle - 30 oz.
# 6                 Accessories           Cleaners       Bike Wash - Dissolver
# 7                 Accessories            Fenders       Fender Set - Mountain
# 8                 Accessories            Helmets       Sport-100 Helmet, Red
# 9                 Accessories    Hydration Packs     Hydration Pack - 70 oz.
# 10                Accessories    Tires and Tubes         Patch Kit/8 Patches
# 11       SubTotal Accessories                All                         All
# 12                      Bikes     Mountain Bikes     Mountain-100 Silver, 38
# 13                      Bikes         Road Bikes            Road-150 Red, 62
# ...

# %%
df2.isnull().sum()
# Out:
# AdventureWorks Budget Data    0
# Subcategory                   0
# Productname                   0
# ProductKey                    0
# Jan2016                       0
# Feb2016                       0
# mar2016                       0
# Apr2016                       0
# May2016                       0
# Jun2016                       0
# jul2016                       0
# Aug2016                       0
# Sep2016                       0
# Oct2016                       0
# Nov2016                       0
# Dec2016                       0
# GrandTotal                    0
# dtype: int64

# %%
# missing values get removed ..

# %%
df2.describe()
# Out:
#        AdventureWorks Budget Data Subcategory Productname  ProductKey  \
# count                          21          21          21          21
# unique                          7          18          18          21
# top                   Accessories         All         All         483
# freq                            8           4           4           1
#
#         Jan2016  Feb2016  mar2016  Apr2016  May2016  Jun2016  jul2016  \
# count        21       21       21       21       21       21       21
# unique       21       21       21       21       21       21       21
# top        1131     2635     4134     2179     2637     3279     2218
# freq          1        1        1        1        1        1        1
#
#         Aug2016  Sep2016  Oct2016  Nov2016  Dec2016  GrandTotal
# count        21       21       21       21       21          21
# unique       21       21       21       21       21          21
# top        3287     3885     2484     5441     3551       36861
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, 3 to 23
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   AdventureWorks Budget Data  21 non-null     object
#  1   Subcategory                 21 non-null     object
#  2   Productname                 21 non-null     object
#  3   ProductKey                  21 non-null     object
#  4   Jan2016                     21 non-null     object
#  5   Feb2016                     21 non-null     object
#  6   mar2016                     21 non-null     object
#  7   Apr2016                     21 non-null     object
#  8   May2016                     21 non-null     object
#  9   Jun2016                     21 non-null     object
#  10  jul2016                     21 non-null     object
#  11  Aug2016                     21 non-null     object
#  12  Sep2016                     21 non-null     object
# ...

# %%
# to compute something firstly we have to change the datatype of sales.
df2 = df2.astype({
    'ProductKey':int,
    'Jan2016':int,
    'Feb2016':int,
    'mar2016':int,
    'Apr2016':int,
    'May2016':int,
    'Jun2016':int,
    'jul2016':int,
    'Aug2016':int,
    'Sep2016':int,
    'Oct2016':int,
    'Nov2016':int,
    'Dec2016':int,
    'GrandTotal':int,
})

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, 3 to 23
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   AdventureWorks Budget Data  21 non-null     object
#  1   Subcategory                 21 non-null     object
#  2   Productname                 21 non-null     object
#  3   ProductKey                  21 non-null     int32
#  4   Jan2016                     21 non-null     int32
#  5   Feb2016                     21 non-null     int32
#  6   mar2016                     21 non-null     int32
#  7   Apr2016                     21 non-null     int32
#  8   May2016                     21 non-null     int32
#  9   Jun2016                     21 non-null     int32
#  10  jul2016                     21 non-null     int32
#  11  Aug2016                     21 non-null     int32
#  12  Sep2016                     21 non-null     int32
# ...

# %%
new_data = df2.select_dtypes(include = 'number')
new_data
# Out:
#     ProductKey  Jan2016  Feb2016  mar2016  Apr2016  May2016  Jun2016  jul2016  \
# 3          483     1131     2635     4134     2179     2637     3279     2218
# 4          486      666     3695     2868     4862     3439     4612     2774
# 5          477     1892     4727     3656     4449     4051     6257     4871
# 6          484      160      713      555      656      369      582      777
# 7          485      970     3014     2809     4259     3638     3721     4190
# 8          212     5317    16221    16752    16552    17204    25354    17584
# 9          487      809     2684     2917     3425     2716     3260     3773
# 10         480     3554    18758    20905    18046    21680    22456    23995
# 11        3594    14499    52447    54596    54428    55734    69521    60182
# 12         344   370105   326786   384811   439822   458523   619456   524348
# 13         310   346295   289524   355097   346783   399691   546092   441037
# ...

# %%
new_data.corr()
# Out:
#             ProductKey   Jan2016   Feb2016   mar2016   Apr2016   May2016  \
# ProductKey    1.000000  0.630714  0.671494  0.666059  0.662972  0.661199
# Jan2016       0.630714  1.000000  0.997293  0.998309  0.995332  0.995975
# Feb2016       0.671494  0.997293  1.000000  0.999826  0.999077  0.999308
# mar2016       0.666059  0.998309  0.999826  1.000000  0.998321  0.998742
# Apr2016       0.662972  0.995332  0.999077  0.998321  1.000000  0.999822
# May2016       0.661199  0.995975  0.999308  0.998742  0.999822  1.000000
# Jun2016       0.658682  0.994098  0.998220  0.997360  0.999530  0.999725
# jul2016       0.660332  0.996773  0.999571  0.999138  0.999828  0.999900
# Aug2016       0.655997  0.992733  0.997114  0.995930  0.999386  0.998682
# Sep2016       0.658444  0.994019  0.998183  0.997269  0.999672  0.999713
# Oct2016       0.657302  0.991006  0.996348  0.994991  0.998928  0.998735
# Nov2016       0.654445  0.993403  0.997463  0.996383  0.999562  0.998989
# ...

# %%
# here we can see that there is positive correlation between each attribute ofdata.

# %%
# we can plot graph between any two attribute

# %%
import matplotlib.pyplot as plt
x = df2['Jan2016']    
y = df2['ProductKey']     
plt.scatter(x,y)

# %%
import matplotlib.pyplot as plt
x = df2['Jun2016']    
y = df2['Dec2016']     
plt.stackplot(x,y)

# %%
# we can see that graph is increasing .

# %%
import matplotlib.pyplot as plt
x = df2['Apr2016']
z = df2['Aug2016']
w = df2['Nov2016']
y = df2['GrandTotal'] 
plt.stackplot(z,y)
plt.stackplot(w,y)
plt.stackplot(x,y)
